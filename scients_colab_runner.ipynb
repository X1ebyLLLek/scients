# %% [markdown]
# # scients Testing Runner
#
# This notebook installs dependencies and runs the `main.py` script to test the model's effectiveness.

# %%
# !pip install -r requirements.txt

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")

# %%
import os

csv_file = "BGL.log_structured.csv"
if not os.path.exists(csv_file):
    print(f"WARNING: {csv_file} not found in current directory.")
    print("Please upload the CSV file ensuring it is in the same folder as this notebook.")
else:
    print(f"Found {csv_file}.")

# %%
# Run the main script
# Adjust epochs as needed for a quick test vs full run
# !python main.py --epochs 5 --data_path "BGL.log_structured.csv"

# %%
from IPython.display import Image
import os

if os.path.exists("performance.png"):
    display(Image(filename="performance.png"))
else:
    print("performance.png not found. Did the script run successfully?")
